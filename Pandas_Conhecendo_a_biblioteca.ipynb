# %% [markdown]
# <a href="https://colab.research.google.com/github/mayconalbuquerque1/mayconalbuquerque1/blob/main/Pandas_Conhecendo_a_biblioteca.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introdução ao Curso - Projeto imobiliária

# %% [markdown]
# Neste curso, trabalharemos como cientistas de dados de uma empresa imobiliária. Vamos desenvolver um projeto em que aprenderemos a:
#
# ```
# - explorar características gerais de uma base de dados
# - realizar análises exploratórias com diferentes métodos
# - lidar com valores nulos
# - remover registros inconsistentes
# - aplicar filtros
# - criar diferentes colunas
# - e muitos mais
# ```
#
#
# Ao final deste curso, você será capaz de desenvolver suas próprias análises utilizando a biblioteca Pandas.
#
# Para que você consiga aproveita todo o conteúdo, é importante que você já tenha conhecimento da linguagem Python, mais voltada para o mundo da ciência de dados.

# %% [markdown]
# #1 Conhecendo a Base de Dados
#
# ---

# %% [markdown]
# O primeiro passo para começarmos o projeto é importar a base de dados e verificar algumas características gerais, como:
#
# quantidade de linhas e colunas;
#
# quais as colunas da base de dados;
#
# explorar as diferentes colunas existentes;
#
# verificar os tipos dos dados.

# %% [markdown]
# ## 1.1 Importando os dados

# %%
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/alura-cursos/pandas-conhecendo-a-biblioteca/main/base-de-dados/aluguel.csv'
pd.read_csv(url)
# Out:
#       Tipo;Bairro;Quartos;Vagas;Suites;Area;Valor;Condominio;IPTU
# 0              Quitinete;Copacabana;1;0;0;40;1700;500;60
# 1                  Casa;Jardim Botânico;2;0;1;100;7000;;
# 2      Conjunto Comercial/Sala;Barra da Tijuca;0;4;0;...
# 3                 Apartamento;Centro;1;0;0;15;800;390;20
# 4             Apartamento;Higienópolis;1;0;0;48;800;230;
# ...                                                  ...
# 32955               Quitinete;Centro;0;0;0;27;800;350;25
# 32956       Apartamento;Jacarepaguá;3;1;2;78;1800;800;40
# 32957  Apartamento;São Francisco Xavier;2;1;0;48;1400...
# 32958              Apartamento;Leblon;2;0;0;70;3000;760;
# 32959  Conjunto Comercial/Sala;Centro;0;0;0;250;6500;...
#
# [32960 rows x 1 columns]

# %%
dados = pd.read_csv(url, sep=';')
dados
# Out:
#                           Tipo                Bairro  Quartos  Vagas  Suites  \
# 0                    Quitinete            Copacabana        1      0       0
# 1                         Casa       Jardim Botânico        2      0       1
# 2      Conjunto Comercial/Sala       Barra da Tijuca        0      4       0
# 3                  Apartamento                Centro        1      0       0
# 4                  Apartamento          Higienópolis        1      0       0
# ...                        ...                   ...      ...    ...     ...
# 32955                Quitinete                Centro        0      0       0
# 32956              Apartamento           Jacarepaguá        3      1       2
# 32957              Apartamento  São Francisco Xavier        2      1       0
# 32958              Apartamento                Leblon        2      0       0
# 32959  Conjunto Comercial/Sala                Centro        0      0       0
#
#        Area   Valor  Condominio    IPTU
# ...

# %%
dados.head()
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
#
#     Valor  Condominio    IPTU
# 0  1700.0       500.0    60.0
# 1  7000.0         NaN     NaN
# 2  5200.0      4020.0  1111.0
# 3   800.0       390.0    20.0
# 4   800.0       230.0     NaN

# %%
dados.tail()
# Out:
#                           Tipo                Bairro  Quartos  Vagas  Suites  \
# 32955                Quitinete                Centro        0      0       0
# 32956              Apartamento           Jacarepaguá        3      1       2
# 32957              Apartamento  São Francisco Xavier        2      1       0
# 32958              Apartamento                Leblon        2      0       0
# 32959  Conjunto Comercial/Sala                Centro        0      0       0
#
#        Area   Valor  Condominio    IPTU
# 32955    27   800.0       350.0    25.0
# 32956    78  1800.0       800.0    40.0
# 32957    48  1400.0       509.0    37.0
# 32958    70  3000.0       760.0     NaN
# 32959   250  6500.0      4206.0  1109.0

# %%
type(dados)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## 1.2 Características gerais da base de dados

# %%
dados.shape
# Out:
# (32960, 9)

# %%
dados.columns
# Out:
# Index(['Tipo', 'Bairro', 'Quartos', 'Vagas', 'Suites', 'Area', 'Valor',
#        'Condominio', 'IPTU'],
#       dtype='object')

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32960 entries, 0 to 32959
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Tipo        32960 non-null  object
#  1   Bairro      32960 non-null  object
#  2   Quartos     32960 non-null  int64
#  3   Vagas       32960 non-null  int64
#  4   Suites      32960 non-null  int64
#  5   Area        32960 non-null  int64
#  6   Valor       32943 non-null  float64
#  7   Condominio  28867 non-null  float64
#  8   IPTU        22723 non-null  float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 2.3+ MB

# %%
dados['Tipo']
# Out:
# 0                      Quitinete
# 1                           Casa
# 2        Conjunto Comercial/Sala
# 3                    Apartamento
# 4                    Apartamento
#                   ...
# 32955                  Quitinete
# 32956                Apartamento
# 32957                Apartamento
# 32958                Apartamento
# 32959    Conjunto Comercial/Sala
# Name: Tipo, Length: 32960, dtype: object

# %%
dados[['Quartos', 'Valor']]
# Out:
#        Quartos   Valor
# 0            1  1700.0
# 1            2  7000.0
# 2            0  5200.0
# 3            1   800.0
# 4            1   800.0
# ...        ...     ...
# 32955        0   800.0
# 32956        3  1800.0
# 32957        2  1400.0
# 32958        2  3000.0
# 32959        0  6500.0
#
# [32960 rows x 2 columns]

# %% [markdown]
# ## Atividade: bora praticar?

# %% [markdown]
# Para praticar os métodos aprendidos no decorrer dessa aula e também aprender novos, vamos realizar algumas análises utilizando um arquivo csv diferente: [Alunos.csv](https://raw.githubusercontent.com/alura-cursos/pandas-conhecendo-a-biblioteca/main/desafios/alunos.csv)

# %% [markdown]
# 1) Importe o arquivo alunos.csv e armazene seu conteúdo em um DataFrame Pandas.
#
# 2) Visualize as primeiras 7 linhas do DataFrame e as 5 últimas.
#
# 3) Confira a quantidade de linhas e colunas desse DataFrame.
#
# 4) Explore as colunas do DataFrame e analise os tipos dos dados presentes em cada coluna.

# %% [markdown]
# Extra: Calcule algumas estatísticas descritivas básicas dos dados do DataFrame (média, desvio padrão, etc).
#
# Dica: pesquise pelo método describe.

# %%
import pandas as pd

# %%
Alunos = pd.read_csv('https://raw.githubusercontent.com/alura-cursos/pandas-conhecendo-a-biblioteca/main/desafios/alunos.csv')
Alunos
# Out:
#          Nome  Idade  Notas  Aprovado
# 0         Ary     20    7.5      True
# 1         Ana     18    NaN     False
# 2       Cátia     27    2.5     False
# 3       Denis     18    5.0     False
# 4        Beto     21   10.0      True
# 5       Bruna     23    NaN     False
# 6        Dara     21    7.0      True
# 7      Carlos     19    6.0      True
# 8       Alice     35    5.6     False
# 9       Vitor     28    NaN     False
# 10     Daniel     21    NaN     False
# 11       Igor     24    4.5     False
# 12  Sthefanie     26    9.5      True
# 13      Mirla     25    9.0      True
# 14      Paulo     37    NaN     False
# 15     Mylena     29    7.0      True
# 16      Lucas     33    NaN     False
# 17      Nadia     34    8.0      True

# %%
Alunos.head(7)
# Out:
#     Nome  Idade  Notas  Aprovado
# 0    Ary     20    7.5      True
# 1    Ana     18    NaN     False
# 2  Cátia     27    2.5     False
# 3  Denis     18    5.0     False
# 4   Beto     21   10.0      True
# 5  Bruna     23    NaN     False
# 6   Dara     21    7.0      True

# %%
Alunos.tail(5)
# Out:
#       Nome  Idade  Notas  Aprovado
# 13   Mirla     25    9.0      True
# 14   Paulo     37    NaN     False
# 15  Mylena     29    7.0      True
# 16   Lucas     33    NaN     False
# 17   Nadia     34    8.0      True

# %%
Alunos.shape
# Out:
# (18, 4)

# %%
Alunos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Nome      18 non-null     object
#  1   Idade     18 non-null     int64
#  2   Notas     12 non-null     float64
#  3   Aprovado  18 non-null     bool
# dtypes: bool(1), float64(1), int64(1), object(1)
# memory usage: 582.0+ bytes

# %%
Alunos.describe()
# Out:
#            Idade      Notas
# count  18.000000  12.000000
# mean   25.500000   6.800000
# std     6.070662   2.204953
# min    18.000000   2.500000
# 25%    21.000000   5.450000
# 50%    24.500000   7.000000
# 75%    28.750000   8.250000
# max    37.000000  10.000000

# %% [markdown]
# # 2 Análise exploratória de dados
#
# ---

# %% [markdown]
# ## 2.1 Qual valor médio de aluguel por tipo de imóvel

# %%
import pandas as pd

# %%
dados = pd.read_csv('https://raw.githubusercontent.com/alura-cursos/pandas-conhecendo-a-biblioteca/main/base-de-dados/aluguel.csv', sep=';')

# %%
dados.head()
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
#
#     Valor  Condominio    IPTU
# 0  1700.0       500.0    60.0
# 1  7000.0         NaN     NaN
# 2  5200.0      4020.0  1111.0
# 3   800.0       390.0    20.0
# 4   800.0       230.0     NaN

# %%
dados['Valor'].mean()
# Out:
# np.float64(12952.659715265761)

# %%
dados.groupby('Tipo')['Valor'].mean(numeric_only=True)
# Out:
# Tipo
# Apartamento                      4744.614648
# Box/Garagem                      1899.756098
# Casa                             6793.454922
# Casa Comercial                  14478.264151
# Casa de Condomínio              11952.061245
# Casa de Vila                     1574.369478
# Chácara                          4900.000000
# Conjunto Comercial/Sala         14715.045521
# Flat                             4546.189076
# Galpão/Depósito/Armazém         53407.062600
# Hotel                           25000.000000
# Indústria                      120000.000000
# Loft                             2557.882353
# Loja Shopping/ Ct Comercial      8126.178862
# Loja/Salão                      13769.646770
# Loteamento/Condomínio           22000.000000
# Pousada/Chalé                    1480.000000
# Prédio Inteiro                 498637.239203
# Quitinete                        1246.840909
# Studio                           2400.000000
# Sítio                           12499.000000
# ...

# %%
dados.groupby('Tipo')[['Valor']].mean(numeric_only=True).sort_values('Valor')
# Out:
#                                      Valor
# Tipo
# Quitinete                      1246.840909
# Pousada/Chalé                  1480.000000
# Casa de Vila                   1574.369478
# Box/Garagem                    1899.756098
# Studio                         2400.000000
# Loft                           2557.882353
# Flat                           4546.189076
# Apartamento                    4744.614648
# Chácara                        4900.000000
# Casa                           6793.454922
# Loja Shopping/ Ct Comercial    8126.178862
# Casa de Condomínio            11952.061245
# Sítio                         12499.000000
# Loja/Salão                    13769.646770
# Casa Comercial                14478.264151
# Conjunto Comercial/Sala       14715.045521
# Loteamento/Condomínio         22000.000000
# Hotel                         25000.000000
# Terreno Padrão                32567.714286
# Galpão/Depósito/Armazém       53407.062600
# Indústria                    120000.000000
# ...

# %%
df_preco_tipo = dados.groupby('Tipo')[['Valor']].mean(numeric_only=True).sort_values('Valor')

# %%
df_preco_tipo.plot(kind='barh', figsize=(10,4), color = 'red', title='Preço médio por tipo de imóvel', )
# Out:
# <Axes: title={'center': 'Preço médio por tipo de imóvel'}, ylabel='Tipo'>

# %% [markdown]
# ## 2.2 Removendo imóveis comerciais

# %%
dados.Tipo.unique()
# Out:
# array(['Quitinete', 'Casa', 'Conjunto Comercial/Sala', 'Apartamento',
#        'Casa de Condomínio', 'Prédio Inteiro', 'Flat', 'Loja/Salão',
#        'Galpão/Depósito/Armazém', 'Casa Comercial', 'Casa de Vila',
#        'Terreno Padrão', 'Box/Garagem', 'Loft',
#        'Loja Shopping/ Ct Comercial', 'Chácara', 'Loteamento/Condomínio',
#        'Sítio', 'Pousada/Chalé', 'Studio', 'Hotel', 'Indústria'],
#       dtype=object)

# %%
imoveis_comerciais = ['Conjunto Comercial/Sala',
                      'Prédio Inteiro', 'Loja/Salão',
                      'Galpão/Depósito/Armazém',
                      'Casa Comercial', 'Terreno Padrão',
                      'Loja Shopping/ Ct Comercial',
                      'Box/Garagem', 'Chácara',
                      'Loteamento/Condomínio', 'Sítio',
                      'Pousada/Chalé', 'Hotel', 'Indústria']

# %%
df = dados.query('@imoveis_comerciais not in Tipo')
df.head()
# Out:
#           Tipo           Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 0    Quitinete       Copacabana        1      0       0    40  1700.0
# 1         Casa  Jardim Botânico        2      0       1   100  7000.0
# 3  Apartamento           Centro        1      0       0    15   800.0
# 4  Apartamento     Higienópolis        1      0       0    48   800.0
# 5  Apartamento     Vista Alegre        3      1       0    70  1200.0
#
#    Condominio  IPTU
# 0       500.0  60.0
# 1         NaN   NaN
# 3       390.0  20.0
# 4       230.0   NaN
# 5         NaN   NaN

# %%
df.Tipo.unique()
# Out:
# array(['Quitinete', 'Casa', 'Apartamento', 'Casa de Condomínio', 'Flat',
#        'Casa de Vila', 'Loft', 'Studio'], dtype=object)

# %%
df_preco_tipo = df.groupby('Tipo')[['Valor']].mean(numeric_only=True).sort_values('Valor')

# %%
df_preco_tipo.plot(kind='barh', figsize=(10,4), color = 'red', title='Preço médio por tipo de imóvel')
# Out:
# <Axes: title={'center': 'Preço médio por tipo de imóvel'}, ylabel='Tipo'>

# %% [markdown]
# ## Atividade - Realizando seleções com query

# %% [markdown]
# O método query é uma ferramenta do Pandas que permite selecionar dados em um DataFrame usando as condições que especificamos. Ele usa uma sintaxe semelhante ao SQL e é útil quando precisamos filtrar nossos dados.
#
# Com base nisso, suponha que o time de ML tenha feito a seguinte solicitação:
#
# **Selecione apenas os imóveis que possuem uma ou mais suítes.**
#
# Qual é a forma correta de realizar essa seleção?

# %%
df_selecao = df.query('Suites >= 1')
df_selecao.head()
# Out:
#                   Tipo               Bairro  Quartos  Vagas  Suites  Area  \
# 1                 Casa      Jardim Botânico        2      0       1   100
# 7   Casa de Condomínio      Barra da Tijuca        5      4       5   750
# 12         Apartamento  Lins de Vasconcelos        3      1       1    90
# 13         Apartamento           Copacabana        1      0       1    40
# 15         Apartamento           Copacabana        4      3       1   243
#
#       Valor  Condominio   IPTU
# 1    7000.0         NaN    NaN
# 7   22000.0         NaN    NaN
# 12   1500.0       455.0   14.0
# 13   2000.0       561.0   50.0
# 15  13000.0      2000.0  803.0

# %%
df_selecao[['Tipo', 'Suites']]
# Out:
#                      Tipo  Suites
# 1                    Casa       1
# 7      Casa de Condomínio       5
# 12            Apartamento       1
# 13            Apartamento       1
# 15            Apartamento       1
# ...                   ...     ...
# 32944         Apartamento       1
# 32947         Apartamento       1
# 32949         Apartamento       2
# 32952  Casa de Condomínio       4
# 32956         Apartamento       2
#
# [13460 rows x 2 columns]

# %% [markdown]
# ## 2.3 Qual o percentual de cada tipo de imóvel presente na base de dados

# %%
df.Tipo.unique()
# Out:
# array(['Quitinete', 'Casa', 'Apartamento', 'Casa de Condomínio', 'Flat',
#        'Casa de Vila', 'Loft', 'Studio'], dtype=object)

# %%
df.Tipo.value_counts(normalize=True)
# Out:
# Tipo
# Apartamento           0.845139
# Casa de Condomínio    0.043096
# Casa                  0.041842
# Quitinete             0.036173
# Flat                  0.020596
# Casa de Vila          0.010774
# Loft                  0.002207
# Studio                0.000173
# Name: proportion, dtype: float64

# %%
df.Tipo.value_counts(normalize=True).to_frame().sort_values('Tipo')
# Out:
#                     proportion
# Tipo
# Apartamento           0.845139
# Casa                  0.041842
# Casa de Condomínio    0.043096
# Casa de Vila          0.010774
# Flat                  0.020596
# Loft                  0.002207
# Quitinete             0.036173
# Studio                0.000173

# %%
df_percentual = df.Tipo.value_counts(normalize=True).sort_values()

df_percentual.plot(kind='barh', figsize=(10,4), color = 'green',
                   xlabel = 'Tipos', ylabel = 'Percenntual')
# Out:
# <Axes: xlabel='Tipos', ylabel='Percenntual'>

# %% [markdown]
# ## 2.4 Selecionando apenas os imóveis do tipo apartamento

# %%
df = df.query('Tipo == "Apartamento"')
df.head()
# Out:
#            Tipo        Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 3   Apartamento        Centro        1      0       0    15   800.0
# 4   Apartamento  Higienópolis        1      0       0    48   800.0
# 5   Apartamento  Vista Alegre        3      1       0    70  1200.0
# 6   Apartamento      Cachambi        2      0       0    50  1300.0
# 10  Apartamento        Centro        1      0       0    36  1200.0
#
#     Condominio  IPTU
# 3        390.0  20.0
# 4        230.0   NaN
# 5          NaN   NaN
# 6        301.0  17.0
# 10         NaN   NaN

# %% [markdown]
# ## Atividade - Métodos da biblioteca Pandas

# %% [markdown]
# A biblioteca Pandas possui diferentes métodos que nos auxiliam no momento de analisar e explorar nossos dados. Utilizando esses métodos, nós conseguimos agrupar os dados, fazer seleções, contar o número de valores únicos, dentre outras coisas.
#
# Suponha que precisamos contar quantas vezes cada bairro aparece na nossa base de dados. Qual método poderíamos utilizar para fazer isso?

# %%
 df['Bairro'].value_counts()
# Out:
# Bairro
# Barra da Tijuca             3341
# Copacabana                  2465
# Ipanema                     1768
# Recreio dos Bandeirantes    1490
# Leblon                      1241
#                             ...
# Parque Anchieta                1
# Caju                           1
# Cidade Jardim                  1
# Coelho Neto                    1
# Grumari                        1
# Name: count, Length: 149, dtype: int64

# %% [markdown]
# ## Atividade - Desafio: bora praticar?

# %% [markdown]
# O time de ML chegou com algumas demandas de última hora para resolvermos nesse momento da análise exploratória. Essas demandas são:
#
# 1. Calcular a média de quartos por apartamento;
#
# 2. Conferir quantos bairros únicos existem na nossa base de dados;
#
# 3. Analisar quais bairros possuem a média de valor de aluguel mais elevadas;
#
# 4. Criar um gráfico de barras horizontais que apresente os 5 bairros com as médias de valores de aluguel mais elevadas.

# %% [markdown]
# ### Calcular a média de quartos por apartamento

# %%
df = dados

# %%
df['Quartos'].mean()
# Out:
# np.float64(1.7713895631067962)

# %% [markdown]
# ### Conferir quantos bairros únicos existem na nossa base de dados

# %%
dados
# Out:
#                           Tipo                Bairro  Quartos  Vagas  Suites  \
# 0                    Quitinete            Copacabana        1      0       0
# 1                         Casa       Jardim Botânico        2      0       1
# 2      Conjunto Comercial/Sala       Barra da Tijuca        0      4       0
# 3                  Apartamento                Centro        1      0       0
# 4                  Apartamento          Higienópolis        1      0       0
# ...                        ...                   ...      ...    ...     ...
# 32955                Quitinete                Centro        0      0       0
# 32956              Apartamento           Jacarepaguá        3      1       2
# 32957              Apartamento  São Francisco Xavier        2      1       0
# 32958              Apartamento                Leblon        2      0       0
# 32959  Conjunto Comercial/Sala                Centro        0      0       0
#
#        Area   Valor  Condominio    IPTU
# ...

# %%
df.Bairro.unique()
# Out:
# array(['Copacabana', 'Jardim Botânico', 'Barra da Tijuca', 'Centro',
#        'Higienópolis', 'Vista Alegre', 'Cachambi', 'Ramos', 'Grajaú',
#        'Lins de Vasconcelos', 'Botafogo', 'Taquara',
#        'Freguesia (Jacarepaguá)', 'Tijuca', 'Olaria', 'Leblon',
#        'São Cristóvão', 'Ipanema', 'Campo Grande',
#        'Recreio dos Bandeirantes', 'Jardim Oceânico', 'Humaitá',
#        'Península', 'Méier', 'Vargem Pequena', 'Maracanã', 'Jacarepaguá',
#        'Vargem Grande', 'São Conrado', 'Maria da Graça', 'Vila Valqueire',
#        'Gávea', 'Cosme Velho', 'Bonsucesso', 'Todos os Santos',
#        'Laranjeiras', 'Itanhangá', 'Flamengo', 'Praça Seca', 'Piedade',
#        'Lagoa', 'Santo Cristo', 'Largo do Machado', 'Catete',
#        'Jardim Carioca', 'Benfica', 'Glória', 'Vila Isabel',
#        'Quintino Bocaiúva', 'São Francisco Xavier', 'Rocha Miranda',
#        'Engenho Novo', 'Engenho de Dentro', 'Cidade Nova', 'Pilares',
# ...

# %%
df['Bairro'].nunique()
# Out:
# 162

# %% [markdown]
# ### Analisar quais bairros possuem a média de valor de aluguel mais elevadas

# %%
dados
# Out:
#                           Tipo                Bairro  Quartos  Vagas  Suites  \
# 0                    Quitinete            Copacabana        1      0       0
# 1                         Casa       Jardim Botânico        2      0       1
# 2      Conjunto Comercial/Sala       Barra da Tijuca        0      4       0
# 3                  Apartamento                Centro        1      0       0
# 4                  Apartamento          Higienópolis        1      0       0
# ...                        ...                   ...      ...    ...     ...
# 32955                Quitinete                Centro        0      0       0
# 32956              Apartamento           Jacarepaguá        3      1       2
# 32957              Apartamento  São Francisco Xavier        2      1       0
# 32958              Apartamento                Leblon        2      0       0
# 32959  Conjunto Comercial/Sala                Centro        0      0       0
#
#        Area   Valor  Condominio    IPTU
# ...

# %%
df = dados

# %%
df.groupby('Bairro')[['Valor']].mean(numeric_only=True).sort_values('Valor', ascending=False).head()
# Out:
#                        Valor
# Bairro
# Jacarepaguá    314143.489637
# Irajá          154610.470588
# Caju           120264.782609
# Vasco da Gama  120000.000000
# Cidade Nova     88166.692308

# %% [markdown]
# ### Criar um gráfico de barras horizontais que apresente os 5 bairros com as médias de valores de aluguel mais elevadas.

# %%
df_bairro = df.groupby('Bairro')[['Valor']].mean(numeric_only=True).sort_values('Valor', ascending=True).head()

# %%
df_bairro.plot(kind='barh', figsize=(10,4), color = 'red', title='Preço médio por tipo de imóvel')
# Out:
# <Axes: title={'center': 'Preço médio por tipo de imóvel'}, ylabel='Bairro'>

# %% [markdown]
# ## Nessa aula aprendi

# %% [markdown]
# *   Identificar o que fazer durante um processo de análise exploratória;
# *   Calcular a média de valores de um DataFrame;
# *   Agrupar os dados de acordo com uma coluna específica utilizando o groupby;
# *   Fazer seleções utilizando o método query;
# *   Transformar Series em DataFrames;
# *   Ordenar valores de um DataFrame com o sort_values;
# *   Plotar gráficos de barras verticais e horizontais;
# *   Visualizar valores únicos com o unique;
# *   Utilizar o value_counts para contar valores únicos e calcular percentuais;
# *   Mudar nomes de colunas.

# %% [markdown]
# # 3 Tratando e filtrando os dados
#
# ---

# %% [markdown]
# ## 3.1 Lidando com dados nulos

# %%
df.isnull()
# Out:
#         Tipo  Bairro  Quartos  Vagas  Suites   Area  Valor  Condominio   IPTU
# 0      False   False    False  False   False  False  False       False  False
# 1      False   False    False  False   False  False  False        True   True
# 2      False   False    False  False   False  False  False       False  False
# 3      False   False    False  False   False  False  False       False  False
# 4      False   False    False  False   False  False  False       False   True
# ...      ...     ...      ...    ...     ...    ...    ...         ...    ...
# 32955  False   False    False  False   False  False  False       False  False
# 32956  False   False    False  False   False  False  False       False  False
# 32957  False   False    False  False   False  False  False       False  False
# 32958  False   False    False  False   False  False  False       False   True
# 32959  False   False    False  False   False  False  False       False  False
#
# [32960 rows x 9 columns]

# %%
df.isnull().sum()
# Out:
# Tipo              0
# Bairro            0
# Quartos           0
# Vagas             0
# Suites            0
# Area              0
# Valor            17
# Condominio     4093
# IPTU          10237
# dtype: int64

# %%
df = df.fillna(0)

# %%
df.isnull().sum()
# Out:
# Tipo          0
# Bairro        0
# Quartos       0
# Vagas         0
# Suites        0
# Area          0
# Valor         0
# Condominio    0
# IPTU          0
# dtype: int64

# %% [markdown]
# # 4 Removendo registros
#
# ---

# %%
df.query('Valor == 0 | Condominio == 0')
# Out:
#                      Tipo                   Bairro  Quartos  Vagas  Suites  \
# 1                    Casa          Jardim Botânico        2      0       1
# 5             Apartamento             Vista Alegre        3      1       0
# 7      Casa de Condomínio          Barra da Tijuca        5      4       5
# 8      Casa de Condomínio                    Ramos        2      2       0
# 10            Apartamento                   Centro        1      0       0
# ...                   ...                      ...      ...    ...     ...
# 32914          Loja/Salão             Campo Grande        0      0       0
# 32928          Loja/Salão                   Leblon        0      0       0
# 32929          Loja/Salão  Freguesia (Jacarepaguá)        0      0       0
# 32931                Casa                   Centro        5      0       1
# 32954         Box/Garagem                   Centro        0      0       0
#
#        Area    Valor  Condominio    IPTU
# ...

# %%
registros_remover = df.query('Valor == 0 | Condominio == 0').index

# %%
df.drop(registros_remover, axis=0, inplace=True)

# %%
df.query('Valor == 0 | Condominio == 0')
# Out:
# Empty DataFrame
# Columns: [Tipo, Bairro, Quartos, Vagas, Suites, Area, Valor, Condominio, IPTU]
# Index: []

# %%
df.drop('Tipo', axis = 1, inplace = True)

# %%
df.head()
# Out:
#             Bairro  Quartos  Vagas  Suites  Area   Valor  Condominio    IPTU
# 0       Copacabana        1      0       0    40  1700.0       500.0    60.0
# 2  Barra da Tijuca        0      4       0   150  5200.0      4020.0  1111.0
# 3           Centro        1      0       0    15   800.0       390.0    20.0
# 4     Higienópolis        1      0       0    48   800.0       230.0     0.0
# 6         Cachambi        2      0       0    50  1300.0       301.0    17.0

# %% [markdown]
# # 5 Aplicar filtros
#
# ---

# %% [markdown]
# ## 5.1 Filtros

# %% [markdown]
# ### **1. Apartamentos que possuem 1 quarto e aluguel menor que 1200**

# %%
df['Quartos'] == 1
# Out:
# 0         True
# 2        False
# 3         True
# 4         True
# 6        False
#          ...
# 32955    False
# 32956    False
# 32957    False
# 32958    False
# 32959    False
# Name: Quartos, Length: 28854, dtype: bool

# %%
selecao1 = df['Quartos'] == 1
df[selecao1]
# Out:
#                 Bairro  Quartos  Vagas  Suites  Area   Valor  Condominio  \
# 0           Copacabana        1      0       0    40  1700.0       500.0
# 3               Centro        1      0       0    15   800.0       390.0
# 4         Higienópolis        1      0       0    48   800.0       230.0
# 13          Copacabana        1      0       1    40  2000.0       561.0
# 14          Copacabana        1      0       0    27  1800.0       501.0
# ...                ...      ...    ...     ...   ...     ...         ...
# 32922  Barra da Tijuca        1      1       0    62  1700.0       945.0
# 32935           Leblon        1      1       1    50  4300.0      1730.0
# 32938       Copacabana        1      0       0    50  1950.0       450.0
# 32945       Copacabana        1      0       0    22  1500.0       286.0
# 32950           Tijuca        1      0       0    28  1000.0       360.0
#
#         IPTU
# 0       60.0
# 3       20.0
# 4        0.0
# 13      50.0
# 14       0.0
# ...

# %%
selecao2 = df['Valor'] < 1200
df[selecao2]
# Out:
#                         Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 3                       Centro        1      0       0    15   800.0
# 4                 Higienópolis        1      0       0    48   800.0
# 19     Freguesia (Jacarepaguá)        3      0       0    54   950.0
# 23                      Olaria        3      1       0    68  1000.0
# 26               São Cristóvão        0      1       0    25  1100.0
# ...                        ...      ...    ...     ...   ...     ...
# 32948                   Centro        0      0       0    32   600.0
# 32950                   Tijuca        1      0       0    28  1000.0
# 32951           Vila Valqueire        2      0       0    52  1000.0
# 32953                    Méier        2      0       0    70   900.0
# 32955                   Centro        0      0       0    27   800.0
#
#        Condominio  IPTU
# 3           390.0  20.0
# 4           230.0   0.0
# 19          300.0  28.0
# 23          670.0   0.0
# ...

# %%
selecao_final = (selecao1) & (selecao2)
df[selecao_final]
# Out:
#              Bairro  Quartos  Vagas  Suites  Area   Valor  Condominio   IPTU
# 3            Centro        1      0       0    15   800.0       390.0   20.0
# 4      Higienópolis        1      0       0    48   800.0       230.0    0.0
# 28           Tijuca        1      0       0    48   750.0       772.0   25.0
# 54           Centro        1      0       0    27   750.0       371.0   19.0
# 94           Centro        1      1       0    37  1100.0       540.0  900.0
# ...             ...      ...    ...     ...   ...     ...         ...    ...
# 32714      Botafogo        1      0       0    21  1000.0       282.0   25.0
# 32763        Glória        1      0       0    10   400.0       107.0   10.0
# 32818      Flamengo        1      0       0    23   900.0       605.0    0.0
# 32844        Centro        1      0       0    24  1100.0       323.0    0.0
# 32950        Tijuca        1      0       0    28  1000.0       360.0   25.0
#
# [835 rows x 8 columns]

# %%
df_1 = df[selecao_final]

# %% [markdown]
# ### **2. Apartamentos que possuem pelo menos 2 quartos, aluguel menor que 3000 e area maior que 70**

# %%
selecao = (df['Quartos'] >= 2 ) & (df['Valor'] < 3000) & (df['Area'] > 70)
df[selecao]
# Out:
#                          Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 12          Lins de Vasconcelos        3      1       1    90  1500.0
# 21                       Tijuca        2      1       0   110  1900.0
# 24                       Tijuca        2      1       0    78  2000.0
# 32                     Botafogo        2      1       0    76  2500.0
# 36     Recreio dos Bandeirantes        3      1       1   105  2300.0
# ...                         ...      ...    ...     ...   ...     ...
# 32934               Jacarepaguá        2      1       1    78  2200.0
# 32940           Barra da Tijuca        2      1       1    85  2250.0
# 32941           Barra da Tijuca        3      2       0    98  2300.0
# 32944  Recreio dos Bandeirantes        3      2       1    88  1550.0
# 32956               Jacarepaguá        3      1       2    78  1800.0
#
#        Condominio   IPTU
# 12          455.0   14.0
# 21          700.0  138.0
# 24          700.0    0.0
# ...

# %%
df_2 = df[selecao]

# %% [markdown]
# # 6 Salvar os dados
# ---

# %% [markdown]
# ## Salvando os dados

# %%
df.to_csv('dados_tratados.csv', index = False)

# %%
pd.read_csv('dados_tratados.csv')
# Out:
#                      Bairro  Quartos  Vagas  Suites  Area   Valor  Condominio  \
# 0                Copacabana        1      0       0    40  1700.0       500.0
# 1           Barra da Tijuca        0      4       0   150  5200.0      4020.0
# 2                    Centro        1      0       0    15   800.0       390.0
# 3              Higienópolis        1      0       0    48   800.0       230.0
# 4                  Cachambi        2      0       0    50  1300.0       301.0
# ...                     ...      ...    ...     ...   ...     ...         ...
# 28849                Centro        0      0       0    27   800.0       350.0
# 28850           Jacarepaguá        3      1       2    78  1800.0       800.0
# 28851  São Francisco Xavier        2      1       0    48  1400.0       509.0
# 28852                Leblon        2      0       0    70  3000.0       760.0
# 28853                Centro        0      0       0   250  6500.0      4206.0
#
#          IPTU
# 0        60.0
# ...

# %%
df.to_csv('dados_tratados.csv', sep =';')

# %% [markdown]
# ## Desafio - Bora praticar?

# %% [markdown]
# Para praticar os métodos aprendidos no decorrer dessa aula e também aprender novos, vamos realizar alguns tratamentos e seleções utilizando um arquivo csv diferente: alunos.csv.
#
# Esse arquivo é o mesmo utilizado para resolução dos desafios da aula 1 e possui dados referentes a alunos de um curso superior.
#
# Com base nisso, solucione os problemas propostos abaixo utilizando os conhecimentos adquiridos até aqui.
#
#
# * Verifique se a base de dados possui dados nulos e, caso tenha, realize o tratamento desses dados nulos da forma que achar mais coerente com a situação - OK
#
# * Os alunos "Alice" e "Carlos", não fazem mais parte da turma. Sendo assim, remova-os da base de dados. - OK
#
# * Aplique um filtro que selecione apenas os alunos que foram aprovados. - OK
#
# * Salve o DataFrame que possui apenas os alunos aprovados em um arquivo csv chamado "alunos_aprovados.csv". - OK

# %% [markdown]
# ### Extração do arquivo

# %%
import pandas as pd

# %%
pd.read_csv('alunos.csv')
# Out:
#          Nome  Idade  Notas  Aprovado
# 0         Ary     20    7.5      True
# 1         Ana     18    NaN     False
# 2       Cátia     27    2.5     False
# 3       Denis     18    5.0     False
# 4        Beto     21   10.0      True
# 5       Bruna     23    NaN     False
# 6        Dara     21    7.0      True
# 7      Carlos     19    6.0      True
# 8       Alice     35    5.6     False
# 9       Vitor     28    NaN     False
# 10     Daniel     21    NaN     False
# 11       Igor     24    4.5     False
# 12  Sthefanie     26    9.5      True
# 13      Mirla     25    9.0      True
# 14      Paulo     37    NaN     False
# 15     Mylena     29    7.0      True
# 16      Lucas     33    NaN     False
# 17      Nadia     34    8.0      True

# %%
alunos = pd.read_csv('alunos.csv')

# %% [markdown]
# ### Validação dos valores nulos

# %%
alunos.isnull()
# Out:
#      Nome  Idade  Notas  Aprovado
# 0   False  False  False     False
# 1   False  False   True     False
# 2   False  False  False     False
# 3   False  False  False     False
# 4   False  False  False     False
# 5   False  False   True     False
# 6   False  False  False     False
# 7   False  False  False     False
# 8   False  False  False     False
# 9   False  False   True     False
# 10  False  False   True     False
# 11  False  False  False     False
# 12  False  False  False     False
# 13  False  False  False     False
# 14  False  False   True     False
# 15  False  False  False     False
# 16  False  False   True     False
# 17  False  False  False     False

# %%
alunos.fillna(0)
# Out:
#          Nome  Idade  Notas  Aprovado
# 0         Ary     20    7.5      True
# 1         Ana     18    0.0     False
# 2       Cátia     27    2.5     False
# 3       Denis     18    5.0     False
# 4        Beto     21   10.0      True
# 5       Bruna     23    0.0     False
# 6        Dara     21    7.0      True
# 7      Carlos     19    6.0      True
# 8       Alice     35    5.6     False
# 9       Vitor     28    0.0     False
# 10     Daniel     21    0.0     False
# 11       Igor     24    4.5     False
# 12  Sthefanie     26    9.5      True
# 13      Mirla     25    9.0      True
# 14      Paulo     37    0.0     False
# 15     Mylena     29    7.0      True
# 16      Lucas     33    0.0     False
# 17      Nadia     34    8.0      True

# %% [markdown]
# ### Retirando os alunos informados

# %%
remover_alunos = alunos.query('Nome == "Alice" | Nome == "Carlos"').index

# %%
alunos.drop(remover_alunos, axis=0, inplace=True)

# %% [markdown]
# ### Filtrar alunos que foramm aprovados

# %%
alunos.query('Aprovado == True')
# Out:
#          Nome  Idade  Notas  Aprovado
# 0         Ary     20    7.5      True
# 4        Beto     21   10.0      True
# 6        Dara     21    7.0      True
# 12  Sthefanie     26    9.5      True
# 13      Mirla     25    9.0      True
# 15     Mylena     29    7.0      True
# 17      Nadia     34    8.0      True

# %%
alunos_aprovados = alunos.query('Aprovado == True')

# %% [markdown]
# ### Salvando planilha de alunos aprovados

# %%
alunos_aprovados.to_csv('alunos_aprovados.csv')

# %% [markdown]
# # 7 Criar colunas numéricas
#
# ---

# %% [markdown]
# ## Criando coluna numérica

# %%
url = 'https://raw.githubusercontent.com/alura-cursos/pandas-conhecendo-a-biblioteca/main/base-de-dados/aluguel.csv'

# %%
dados = pd.read_csv(url, sep=';')
dados.head()
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
#
#     Valor  Condominio    IPTU
# 0  1700.0       500.0    60.0
# 1  7000.0         NaN     NaN
# 2  5200.0      4020.0  1111.0
# 3   800.0       390.0    20.0
# 4   800.0       230.0     NaN

# %%
dados['Valor_por_mes'] = dados['Valor'] + dados['Condominio']
dados.head()
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
#
#     Valor  Condominio    IPTU  Valor_por_mes
# 0  1700.0       500.0    60.0         2200.0
# 1  7000.0         NaN     NaN            NaN
# 2  5200.0      4020.0  1111.0         9220.0
# 3   800.0       390.0    20.0         1190.0
# 4   800.0       230.0     NaN         1030.0

# %%
dados['Valor_por_ano'] = dados['Valor_por_mes'] * 12 + dados['IPTU']

# %%
dados.head()
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
#
#     Valor  Condominio    IPTU  Valor_por_mes  Valor_por_ano
# 0  1700.0       500.0    60.0         2200.0        26460.0
# 1  7000.0         NaN     NaN            NaN            NaN
# 2  5200.0      4020.0  1111.0         9220.0       111751.0
# 3   800.0       390.0    20.0         1190.0        14300.0
# 4   800.0       230.0     NaN         1030.0            NaN

# %% [markdown]
# ## Criando colunas categóricas

# %%
dados['Descricao'] = dados['Tipo'] + ' em ' + dados['Bairro']
dados.head()
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
#
#     Valor  Condominio    IPTU  Valor_por_mes  Valor_por_ano  \
# 0  1700.0       500.0    60.0         2200.0        26460.0
# 1  7000.0         NaN     NaN            NaN            NaN
# 2  5200.0      4020.0  1111.0         9220.0       111751.0
# 3   800.0       390.0    20.0         1190.0        14300.0
# 4   800.0       230.0     NaN         1030.0            NaN
#
#                                     Descricao
# 0                     Quitinete em Copacabana
# 1                     Casa em Jardim Botânico
# ...

# %%
dados['Descricao'] = dados['Tipo'] + ' em ' + dados['Bairro'] + ' com ' + \
                      dados['Quartos'].astype(str) + ' quartos' + \
                      ' e ' + dados['Vagas'].astype(str) + ' vagas de garagem.'

dados.head()
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
#
#     Valor  Condominio    IPTU  Valor_por_mes  Valor_por_ano  \
# 0  1700.0       500.0    60.0         2200.0        26460.0
# 1  7000.0         NaN     NaN            NaN            NaN
# 2  5200.0      4020.0  1111.0         9220.0       111751.0
# 3   800.0       390.0    20.0         1190.0        14300.0
# 4   800.0       230.0     NaN         1030.0            NaN
#
#                                            Descricao
# 0  Quitinete em Copacabana com 1 quartos e 0 vaga...
# ...

# %%
dados['Possui_suite'] = dados['Suites'].apply(lambda x: 'Sim' if x > 0 else 'Não')
dados.head()
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
#
#     Valor  Condominio    IPTU  Valor_por_mes  Valor_por_ano  \
# 0  1700.0       500.0    60.0         2200.0        26460.0
# 1  7000.0         NaN     NaN            NaN            NaN
# 2  5200.0      4020.0  1111.0         9220.0       111751.0
# 3   800.0       390.0    20.0         1190.0        14300.0
# 4   800.0       230.0     NaN         1030.0            NaN
#
#                                            Descricao Possui_suite
# 0  Quitinete em Copacabana com 1 quartos e 0 vaga...          Não
# ...

# %%
dados.to_csv('dados_completo_dev.csv', index=False, sep=';')

# %% [markdown]
# ## Desafio: bora praticar?

# %% [markdown]
# Para praticar os métodos aprendidos no decorrer dessa aula e também aprender novos, vamos realizar alguns tratamentos e seleções utilizando um arquivo csv diferente: alunos.csv.
#
# Esse arquivo é o mesmo utilizado para resolução dos desafios da aula 1 e 3 e possui dados referentes a alunos de um curso superior. Com base nisso, solucione os problemas propostos abaixo utilizando os conhecimentos adquiridos até aqui.
#
# * 1) Os alunos participaram de uma atividade extracurricular e ganharam pontos extras. Esses pontos extras correspondem a 40% da nota atual de cada um deles. Com base nisso, crie uma coluna chamada "Pontos_extras" que contenha os pontos extras de cada aluno, ou seja, 40% da nota atual deles. - OK
#
# * 2) Crie mais uma coluna, chamada "Notas_finais" que possua as notas de cada aluno somada com os pontos extras. - OK
#
# * 3) Como houve uma pontuação extra, alguns alunos que não tinham sido aprovados antes podem ter sido aprovados agora. Com base nisso, crie uma coluna chamada "Aprovado_final" com os seguintes valores: - OK
#
#     True: caso o aluno esteja aprovado (nota final deve ser maior ou igual a 6);
#
#     False: caso o aluno esteja reprovado (nota final deve ser menor que 6).
#
# * 4) Faça uma seleção e verifique quais alunos não tinham sido aprovados anteriormente, mas foram aprovados após a soma dos pontos extras.

# %% [markdown]
# ### Extração do arquivo

# %%
url = 'https://raw.githubusercontent.com/alura-cursos/pandas-conhecendo-a-biblioteca/main/desafios/alunos.csv'

# %%
alunos = pd.read_csv(url)
alunos.head()
# Out:
#     Nome  Idade  Notas  Aprovado
# 0    Ary     20    7.5      True
# 1    Ana     18    NaN     False
# 2  Cátia     27    2.5     False
# 3  Denis     18    5.0     False
# 4   Beto     21   10.0      True

# %% [markdown]
# ### Validação dos valores nulos

# %%
alunos.fillna(0)
# Out:
#          Nome  Idade  Notas  Aprovado
# 0         Ary     20    7.5      True
# 1         Ana     18    0.0     False
# 2       Cátia     27    2.5     False
# 3       Denis     18    5.0     False
# 4        Beto     21   10.0      True
# 5       Bruna     23    0.0     False
# 6        Dara     21    7.0      True
# 7      Carlos     19    6.0      True
# 8       Alice     35    5.6     False
# 9       Vitor     28    0.0     False
# 10     Daniel     21    0.0     False
# 11       Igor     24    4.5     False
# 12  Sthefanie     26    9.5      True
# 13      Mirla     25    9.0      True
# 14      Paulo     37    0.0     False
# 15     Mylena     29    7.0      True
# 16      Lucas     33    0.0     False
# 17      Nadia     34    8.0      True

# %% [markdown]
# ## Criação da coluna de ponto extra 40%

# %%
alunos['Pontos_extras'] = alunos['Notas'] * 0.4

# %% [markdown]
# ## Criação da coluna Notas Finais

# %%
alunos['Notas_finais'] = alunos['Notas'] + alunos['Pontos_extras']

# %% [markdown]
# ## Atualização dos Aprovados Finais

# %%
alunos['Aprovado'] = alunos['Notas_finais'].apply(lambda x: True if x >= 6 else False)

# %%
alunos.head()
# Out:
#     Nome  Idade  Notas  Aprovado  Pontos_extras  Notas_finais
# 0    Ary     20    7.5      True            3.0          10.5
# 1    Ana     18    NaN     False            NaN           NaN
# 2  Cátia     27    2.5     False            1.0           3.5
# 3  Denis     18    5.0      True            2.0           7.0
# 4   Beto     21   10.0      True            4.0          14.0
